# %% [markdown]
# # Task: saliency map via occlusion
#
# In this task, you have a trained classifier and want to identify which parts of an image most influenced its prediction for a specific class. A simple method for this is to occlude portions of the image and observe the decrease in the predicted class probability compared to the original image's probability.
#
# Create a heatmap of those occlusions:
# * Take the original image (168×224) and replace a square of size 20×20 centered at point (i,j) (and cropped to the image frame) with a value of your choice.
# * Pass the image through the network and calculate the drop in the probability of class `GOLDFISH_LABEL`.
# * Do this with overlapping squares, with centers that cover the whole image, on a grid with stride 10: ((0,0), (0,10), ..., (10,0), (10,10), ..., (170,230)).
# * Return the heatmap as a 2D np.array (of shape (18, 24)).
#
# This should run under 2 minutes on CPU.

# %% [markdown]
# ## Definitions

# %%
import PIL.Image
import matplotlib.pyplot as plt
import numpy as np
import requests
import torch
import torch.nn
from PIL import Image
from torch import Tensor
from torchvision.transforms import v2
from torchvision.models import mobilenet_v2, MobileNet_V2_Weights
from typing import cast

from timm.data.constants import IMAGENET_DEFAULT_MEAN, IMAGENET_DEFAULT_STD


GOLDFISH_LABEL = MobileNet_V2_Weights.DEFAULT.meta["categories"].index("goldfish")


def get_image(
    url: str = "http://www.mimuw.edu.pl/~cygan/welonka.jpg",
    target_max_size: int = 224
) -> Tensor:
    """Return image as tensor of shape (C=3, H, W), normalized values."""
    img = Image.open(requests.get(url, stream=True).raw).convert("RGB")
    transformations = v2.Compose([
        v2.Resize(size=None, max_size=target_max_size),
        v2.ToImage(),
        v2.ToDtype(torch.float32, scale=True),  # scale to 0..1
        v2.Normalize(
            mean=IMAGENET_DEFAULT_MEAN,
            std=IMAGENET_DEFAULT_STD
        ),
    ])
    return cast(Tensor, transformations(img))


def tensor_to_pil(image: Tensor) -> PIL.Image.Image:
    """Convert normalized image tensor of shape (C, H, W) to PIL Image."""
    C, H, W = image.shape
    image = image.detach().permute(1, 2, 0).clone()  # to (H, W, C)
    image *= torch.tensor(IMAGENET_DEFAULT_STD)
    image += torch.tensor(IMAGENET_DEFAULT_MEAN)
    img = PIL.Image.fromarray((image.numpy() * 255).astype(np.uint8))
    return img


DEFAULT_DEVICE = "cuda:0" if torch.cuda.is_available() else "cpu"

def get_model(training: bool = False, device: str = DEFAULT_DEVICE) -> torch.nn.Module:
    model = mobilenet_v2(weights=MobileNet_V2_Weights.DEFAULT)
    model.to(torch.device(device))
    model.train(training)
    return model


def plot_heatmap(heatmap: np.ndarray) -> None:
    plt.matshow(heatmap)
    plt.colorbar()
    plt.show()


def plot_heatmap_over_image(image: Tensor, heatmap: np.ndarray, stride: int = 10, zoom: float = 2.0) -> None:
    """Show heatmap over image."""
    C, H, W = image.shape
    rows, cols = heatmap.shape

    heatmap = heatmap - np.min(heatmap)
    heatmap = heatmap / (np.max(heatmap) + 1e-8)
    heatmap = plt.get_cmap("viridis")(heatmap)
    heatmap_image = PIL.Image.fromarray((heatmap * 255).astype(np.uint8))
    heatmap_image = heatmap_image.resize((cols * stride, rows * stride), resample=PIL.Image.NEAREST)
    heatmap_image = heatmap_image.crop((stride // 2, stride // 2, W + stride // 2, H + stride // 2))
    result = PIL.Image.blend(tensor_to_pil(image).convert("RGBA"), heatmap_image, alpha=0.8)
    result = result.resize((int(W * zoom), int(H * zoom)))
    display(result)

# %% [markdown]
# ## Your code

# %%
def generate_heatmap(model: torch.nn.Module, image: Tensor, stride: int = 10, window: int = 20) -> np.ndarray:
    """Return heatmap of shape (18, 24)."""
    # YOUR CODE STARTS HERE
    heatmap = np.zeros((18, 24))
    ogPred = model(image.unsqueeze(0)).squeeze(0)
    ogPred = ogPred[GOLDFISH_LABEL]
    heatmap = np.zeros((18, 24))

    print("Test: ", image[0,150:168,0:20].shape)

    # it tells me to detach it but lets see when i dont
    for y in range(23):
      for x in range(17):
        # now we want to compute the black square of 20 x 20
        sqr = torch.full((20,20),255)
        # now put the square onto the images copy
        cpImg = image.clone()
        startPointX = x * stride
        startPointY = y * stride
        endPointX = startPointX + 20
        endPointY = startPointY + 20
        print("Start Point: ", startPointX, startPointY)
        print("End Point: ", endPointX, endPointY)

        if(endPointX >= 168):
          endPointX = 168
        if(endPointY >= 224):
          endPointY = 224

        print("END POINT: ", endPointX)
        cpImg[0, startPointX: endPointX, startPointY: endPointY] = sqr[0:endPointX - startPointX, 0:endPointY - startPointY] # here it breaks when we access x = 170
        # now make a prediction on the image
        pred = model(cpImg.unsqueeze(0)).squeeze(0)
        pred = pred[GOLDFISH_LABEL]
        #pred = torch.softmax(pred,dim=0)
        print("Prediction on the modified image at point: ", x," : ",y, " is: ", pred.item())
        drop = ogPred.item() - pred.item()
        print("STOPS WORKING")
        heatmap[x,y] = drop
        print("Works! ")



    # YOUR CODE ENDS HERE
    return heatmap

# %% [markdown]
# ## Test

# %%
image = get_image()
model = get_model()
heatmap = generate_heatmap(model, image)

plt.imshow(tensor_to_pil(image))
plot_heatmap(heatmap)
plot_heatmap_over_image(image, heatmap)
# Out:
# Test:  torch.Size([18, 20])
# Start Point:  0 0
# End Point:  20 20
# END POINT:  20
# Prediction on the modified image at point:  0  :  0  is:  8.291877746582031
# STOPS WORKING
# Works!
# Start Point:  10 0
# End Point:  30 20
# END POINT:  30
# Prediction on the modified image at point:  1  :  0  is:  8.389601707458496
# STOPS WORKING
# Works!
# Start Point:  20 0
# End Point:  40 20
# END POINT:  40
# Prediction on the modified image at point:  2  :  0  is:  8.374442100524902
# STOPS WORKING
# Works!
# Start Point:  30 0
# End Point:  50 20
# END POINT:  50
# Prediction on the modified image at point:  3  :  0  is:  8.30791187286377
# STOPS WORKING
# Works!
# Start Point:  40 0
# End Point:  60 20
# END POINT:  60
# Prediction on the modified image at point:  4  :  0  is:  8.394574165344238
# STOPS WORKING
# Works!
# Start Point:  50 0
# End Point:  70 20
# END POINT:  70
# Prediction on the modified image at point:  5  :  0  is:  8.313201904296875
# STOPS WORKING
# Works!
# Start Point:  60 0
# End Point:  80 20
# END POINT:  80
# Prediction on the modified image at point:  6  :  0  is:  8.321367263793945
# STOPS WORKING
# Works!
# Start Point:  70 0
# End Point:  90 20
# END POINT:  90
# Prediction on the modified image at point:  7  :  0  is:  8.349263191223145
# STOPS WORKING
# Works!
# Start Point:  80 0
# End Point:  100 20
# END POINT:  100
# Prediction on the modified image at point:  8  :  0  is:  8.414042472839355
# STOPS WORKING
# Works!
# Start Point:  90 0
# End Point:  110 20
# END POINT:  110
# Prediction on the modified image at point:  9  :  0  is:  8.266887664794922
# STOPS WORKING
# Works!
# Start Point:  100 0
# End Point:  120 20
# END POINT:  120
# Prediction on the modified image at point:  10  :  0  is:  8.397284507751465
# STOPS WORKING
# Works!
# Start Point:  110 0
# End Point:  130 20
# END POINT:  130
# Prediction on the modified image at point:  11  :  0  is:  8.141510963439941
# STOPS WORKING
# Works!
# Start Point:  120 0
# End Point:  140 20
# END POINT:  140
# Prediction on the modified image at point:  12  :  0  is:  8.320477485656738
# STOPS WORKING
# Works!
# Start Point:  130 0
# End Point:  150 20
# END POINT:  150
# Prediction on the modified image at point:  13  :  0  is:  8.263346672058105
# STOPS WORKING
# Works!
# Start Point:  140 0
# End Point:  160 20
# END POINT:  160
# Prediction on the modified image at point:  14  :  0  is:  8.21108627319336
# STOPS WORKING
# Works!
# Start Point:  150 0
# End Point:  170 20
# END POINT:  168
# Prediction on the modified image at point:  15  :  0  is:  8.228759765625
# STOPS WORKING
# Works!
# Start Point:  160 0
# End Point:  180 20
# END POINT:  168
# Prediction on the modified image at point:  16  :  0  is:  8.193613052368164
# STOPS WORKING
# Works!
# Start Point:  0 10
# End Point:  20 30
# END POINT:  20
# Prediction on the modified image at point:  0  :  1  is:  8.19791030883789
# STOPS WORKING
# Works!
# Start Point:  10 10
# End Point:  30 30
# END POINT:  30
# Prediction on the modified image at point:  1  :  1  is:  8.229796409606934
# STOPS WORKING
# Works!
# Start Point:  20 10
# End Point:  40 30
# END POINT:  40
# Prediction on the modified image at point:  2  :  1  is:  8.118825912475586
# STOPS WORKING
# Works!
# Start Point:  30 10
# End Point:  50 30
# END POINT:  50
# Prediction on the modified image at point:  3  :  1  is:  8.22744369506836
# STOPS WORKING
# Works!
# Start Point:  40 10
# End Point:  60 30
# END POINT:  60
# Prediction on the modified image at point:  4  :  1  is:  8.315648078918457
# STOPS WORKING
# Works!
# Start Point:  50 10
# End Point:  70 30
# END POINT:  70
# Prediction on the modified image at point:  5  :  1  is:  8.300284385681152
# STOPS WORKING
# Works!
# Start Point:  60 10
# End Point:  80 30
# END POINT:  80
# Prediction on the modified image at point:  6  :  1  is:  8.49513053894043
# STOPS WORKING
# Works!
# Start Point:  70 10
# End Point:  90 30
# END POINT:  90
# Prediction on the modified image at point:  7  :  1  is:  8.503684043884277
# STOPS WORKING
# Works!
# Start Point:  80 10
# End Point:  100 30
# END POINT:  100
# Prediction on the modified image at point:  8  :  1  is:  8.668296813964844
# STOPS WORKING
# Works!
# Start Point:  90 10
# End Point:  110 30
# END POINT:  110
# Prediction on the modified image at point:  9  :  1  is:  8.432538032531738
# STOPS WORKING
# Works!
# Start Point:  100 10
# End Point:  120 30
# END POINT:  120
# Prediction on the modified image at point:  10  :  1  is:  8.339853286743164
# STOPS WORKING
# Works!
# Start Point:  110 10
# End Point:  130 30
# END POINT:  130
# Prediction on the modified image at point:  11  :  1  is:  8.468766212463379
# STOPS WORKING
# Works!
# Start Point:  120 10
# End Point:  140 30
# END POINT:  140
# Prediction on the modified image at point:  12  :  1  is:  8.313210487365723
# STOPS WORKING
# Works!
# Start Point:  130 10
# End Point:  150 30
# END POINT:  150
# Prediction on the modified image at point:  13  :  1  is:  8.197415351867676
# STOPS WORKING
# Works!
# Start Point:  140 10
# End Point:  160 30
# END POINT:  160
# Prediction on the modified image at point:  14  :  1  is:  8.286519050598145
# STOPS WORKING
# Works!
# Start Point:  150 10
# End Point:  170 30
# END POINT:  168
# Prediction on the modified image at point:  15  :  1  is:  8.348424911499023
# STOPS WORKING
# Works!
# Start Point:  160 10
# End Point:  180 30
# END POINT:  168
# Prediction on the modified image at point:  16  :  1  is:  8.223088264465332
# STOPS WORKING
# Works!
# Start Point:  0 20
# End Point:  20 40
# END POINT:  20
# Prediction on the modified image at point:  0  :  2  is:  8.143301963806152
# STOPS WORKING
# Works!
# Start Point:  10 20
# End Point:  30 40
# END POINT:  30
# Prediction on the modified image at point:  1  :  2  is:  8.187263488769531
# STOPS WORKING
# Works!
# Start Point:  20 20
# End Point:  40 40
# END POINT:  40
# Prediction on the modified image at point:  2  :  2  is:  8.105034828186035
# STOPS WORKING
# Works!
# Start Point:  30 20
# End Point:  50 40
# END POINT:  50
# Prediction on the modified image at point:  3  :  2  is:  8.102438926696777
# STOPS WORKING
# Works!
# Start Point:  40 20
# End Point:  60 40
# END POINT:  60
# Prediction on the modified image at point:  4  :  2  is:  7.991181373596191
# STOPS WORKING
# Works!
# Start Point:  50 20
# End Point:  70 40
# END POINT:  70
# Prediction on the modified image at point:  5  :  2  is:  8.191253662109375
# STOPS WORKING
# Works!
# Start Point:  60 20
# End Point:  80 40
# END POINT:  80
# Prediction on the modified image at point:  6  :  2  is:  8.130912780761719
# STOPS WORKING
# Works!
# Start Point:  70 20
# End Point:  90 40
# END POINT:  90
# Prediction on the modified image at point:  7  :  2  is:  8.313030242919922
# STOPS WORKING
# Works!
# Start Point:  80 20
# End Point:  100 40
# END POINT:  100
# Prediction on the modified image at point:  8  :  2  is:  8.482898712158203
# STOPS WORKING
# Works!
# Start Point:  90 20
# End Point:  110 40
# END POINT:  110
# Prediction on the modified image at point:  9  :  2  is:  8.354314804077148
# STOPS WORKING
# Works!
# Start Point:  100 20
# End Point:  120 40
# END POINT:  120
# Prediction on the modified image at point:  10  :  2  is:  8.404484748840332
# STOPS WORKING
# Works!
# Start Point:  110 20
# End Point:  130 40
# END POINT:  130
# Prediction on the modified image at point:  11  :  2  is:  8.205986976623535
# STOPS WORKING
# Works!
# Start Point:  120 20
# End Point:  140 40
# END POINT:  140
# Prediction on the modified image at point:  12  :  2  is:  8.33716869354248
# STOPS WORKING
# Works!
# Start Point:  130 20
# End Point:  150 40
# END POINT:  150
# Prediction on the modified image at point:  13  :  2  is:  8.32909870147705
# STOPS WORKING
# Works!
# Start Point:  140 20
# End Point:  160 40
# END POINT:  160
# Prediction on the modified image at point:  14  :  2  is:  8.382566452026367
# STOPS WORKING
# Works!
# Start Point:  150 20
# End Point:  170 40
# END POINT:  168
# Prediction on the modified image at point:  15  :  2  is:  8.458268165588379
# STOPS WORKING
# Works!
# Start Point:  160 20
# End Point:  180 40
# END POINT:  168
# Prediction on the modified image at point:  16  :  2  is:  8.295190811157227
# STOPS WORKING
# Works!
# Start Point:  0 30
# End Point:  20 50
# END POINT:  20
# Prediction on the modified image at point:  0  :  3  is:  8.170231819152832
# STOPS WORKING
# Works!
# Start Point:  10 30
# End Point:  30 50
# END POINT:  30
# Prediction on the modified image at point:  1  :  3  is:  8.130194664001465
# STOPS WORKING
# Works!
# Start Point:  20 30
# End Point:  40 50
# END POINT:  40
# Prediction on the modified image at point:  2  :  3  is:  8.118668556213379
# STOPS WORKING
# Works!
# Start Point:  30 30
# End Point:  50 50
# END POINT:  50
# Prediction on the modified image at point:  3  :  3  is:  8.202166557312012
# STOPS WORKING
# Works!
# Start Point:  40 30
# End Point:  60 50
# END POINT:  60
# Prediction on the modified image at point:  4  :  3  is:  8.022028923034668
# STOPS WORKING
# Works!
# Start Point:  50 30
# End Point:  70 50
# END POINT:  70
# Prediction on the modified image at point:  5  :  3  is:  7.986170768737793
# STOPS WORKING
# Works!
# Start Point:  60 30
# End Point:  80 50
# END POINT:  80
# Prediction on the modified image at point:  6  :  3  is:  8.223111152648926
# STOPS WORKING
# Works!
# Start Point:  70 30
# End Point:  90 50
# END POINT:  90
# Prediction on the modified image at point:  7  :  3  is:  8.480951309204102
# STOPS WORKING
# Works!
# Start Point:  80 30
# End Point:  100 50
# END POINT:  100
# Prediction on the modified image at point:  8  :  3  is:  8.329364776611328
# STOPS WORKING
# Works!
# Start Point:  90 30
# End Point:  110 50
# END POINT:  110
# Prediction on the modified image at point:  9  :  3  is:  8.274495124816895
# STOPS WORKING
# Works!
# Start Point:  100 30
# End Point:  120 50
# END POINT:  120
# Prediction on the modified image at point:  10  :  3  is:  8.0612154006958
# STOPS WORKING
# Works!
# Start Point:  110 30
# End Point:  130 50
# END POINT:  130
# Prediction on the modified image at point:  11  :  3  is:  8.200672149658203
# STOPS WORKING
# Works!
# Start Point:  120 30
# End Point:  140 50
# END POINT:  140
# Prediction on the modified image at point:  12  :  3  is:  8.386307716369629
# STOPS WORKING
# Works!
# Start Point:  130 30
# End Point:  150 50
# END POINT:  150
# Prediction on the modified image at point:  13  :  3  is:  8.342418670654297
# STOPS WORKING
# Works!
# Start Point:  140 30
# End Point:  160 50
# END POINT:  160
# Prediction on the modified image at point:  14  :  3  is:  8.363751411437988
# STOPS WORKING
# Works!
# Start Point:  150 30
# End Point:  170 50
# END POINT:  168
# Prediction on the modified image at point:  15  :  3  is:  8.378660202026367
# STOPS WORKING
# Works!
# Start Point:  160 30
# End Point:  180 50
# END POINT:  168
# Prediction on the modified image at point:  16  :  3  is:  8.338519096374512
# STOPS WORKING
# Works!
# Start Point:  0 40
# End Point:  20 60
# END POINT:  20
# Prediction on the modified image at point:  0  :  4  is:  8.164044380187988
# STOPS WORKING
# Works!
# Start Point:  10 40
# End Point:  30 60
# END POINT:  30
# Prediction on the modified image at point:  1  :  4  is:  8.104241371154785
# STOPS WORKING
# Works!
# Start Point:  20 40
# End Point:  40 60
# END POINT:  40
# Prediction on the modified image at point:  2  :  4  is:  8.056561470031738
# STOPS WORKING
# Works!
# Start Point:  30 40
# End Point:  50 60
# END POINT:  50
# Prediction on the modified image at point:  3  :  4  is:  8.01140022277832
# STOPS WORKING
# Works!
# Start Point:  40 40
# End Point:  60 60
# END POINT:  60
# Prediction on the modified image at point:  4  :  4  is:  8.01313304901123
# STOPS WORKING
# Works!
# Start Point:  50 40
# End Point:  70 60
# END POINT:  70
# Prediction on the modified image at point:  5  :  4  is:  8.085349082946777
# STOPS WORKING
# Works!
# Start Point:  60 40
# End Point:  80 60
# END POINT:  80
# Prediction on the modified image at point:  6  :  4  is:  8.100175857543945
# STOPS WORKING
# Works!
# Start Point:  70 40
# End Point:  90 60
# END POINT:  90
# Prediction on the modified image at point:  7  :  4  is:  8.18686580657959
# STOPS WORKING
# Works!
# Start Point:  80 40
# End Point:  100 60
# END POINT:  100
# Prediction on the modified image at point:  8  :  4  is:  8.055611610412598
# STOPS WORKING
# Works!
# Start Point:  90 40
# End Point:  110 60
# END POINT:  110
# Prediction on the modified image at point:  9  :  4  is:  7.989126205444336
# STOPS WORKING
# Works!
# Start Point:  100 40
# End Point:  120 60
# END POINT:  120
# Prediction on the modified image at point:  10  :  4  is:  7.886051177978516
# STOPS WORKING
# Works!
# Start Point:  110 40
# End Point:  130 60
# END POINT:  130
# Prediction on the modified image at point:  11  :  4  is:  8.306000709533691
# STOPS WORKING
# Works!
# Start Point:  120 40
# End Point:  140 60
# END POINT:  140
# Prediction on the modified image at point:  12  :  4  is:  8.142435073852539
# STOPS WORKING
# Works!
# Start Point:  130 40
# End Point:  150 60
# END POINT:  150
# Prediction on the modified image at point:  13  :  4  is:  8.273369789123535
# STOPS WORKING
# Works!
# Start Point:  140 40
# End Point:  160 60
# END POINT:  160
# Prediction on the modified image at point:  14  :  4  is:  8.254006385803223
# STOPS WORKING
# Works!
# Start Point:  150 40
# End Point:  170 60
# END POINT:  168
# Prediction on the modified image at point:  15  :  4  is:  8.2351655960083
# STOPS WORKING
# Works!
# Start Point:  160 40
# End Point:  180 60
# END POINT:  168
# Prediction on the modified image at point:  16  :  4  is:  8.324671745300293
# STOPS WORKING
# Works!
# Start Point:  0 50
# End Point:  20 70
# END POINT:  20
# Prediction on the modified image at point:  0  :  5  is:  8.125199317932129
# STOPS WORKING
# Works!
# Start Point:  10 50
# End Point:  30 70
# END POINT:  30
# Prediction on the modified image at point:  1  :  5  is:  8.067255973815918
# STOPS WORKING
# Works!
# Start Point:  20 50
# End Point:  40 70
# END POINT:  40
# Prediction on the modified image at point:  2  :  5  is:  8.043417930603027
# STOPS WORKING
# Works!
# Start Point:  30 50
# End Point:  50 70
# END POINT:  50
# Prediction on the modified image at point:  3  :  5  is:  8.04209041595459
# STOPS WORKING
# Works!
# Start Point:  40 50
# End Point:  60 70
# END POINT:  60
# Prediction on the modified image at point:  4  :  5  is:  7.924891471862793
# STOPS WORKING
# Works!
# Start Point:  50 50
# End Point:  70 70
# END POINT:  70
# Prediction on the modified image at point:  5  :  5  is:  7.947052478790283
# STOPS WORKING
# Works!
# Start Point:  60 50
# End Point:  80 70
# END POINT:  80
# Prediction on the modified image at point:  6  :  5  is:  8.09962272644043
# STOPS WORKING
# Works!
# Start Point:  70 50
# End Point:  90 70
# END POINT:  90
# Prediction on the modified image at point:  7  :  5  is:  8.192646026611328
# STOPS WORKING
# Works!
# Start Point:  80 50
# End Point:  100 70
# END POINT:  100
# Prediction on the modified image at point:  8  :  5  is:  8.035395622253418
# STOPS WORKING
# Works!
# Start Point:  90 50
# End Point:  110 70
# END POINT:  110
# Prediction on the modified image at point:  9  :  5  is:  8.041845321655273
# STOPS WORKING
# Works!
# Start Point:  100 50
# End Point:  120 70
# END POINT:  120
# Prediction on the modified image at point:  10  :  5  is:  8.11610221862793
# STOPS WORKING
# Works!
# Start Point:  110 50
# End Point:  130 70
# END POINT:  130
# Prediction on the modified image at point:  11  :  5  is:  8.298137664794922
# STOPS WORKING
# Works!
# Start Point:  120 50
# End Point:  140 70
# END POINT:  140
# Prediction on the modified image at point:  12  :  5  is:  8.095946311950684
# STOPS WORKING
# Works!
# Start Point:  130 50
# End Point:  150 70
# END POINT:  150
# Prediction on the modified image at point:  13  :  5  is:  8.165538787841797
# STOPS WORKING
# Works!
# Start Point:  140 50
# End Point:  160 70
# END POINT:  160
# Prediction on the modified image at point:  14  :  5  is:  8.354392051696777
# STOPS WORKING
# Works!
# Start Point:  150 50
# End Point:  170 70
# END POINT:  168
# Prediction on the modified image at point:  15  :  5  is:  8.270429611206055
# STOPS WORKING
# Works!
# Start Point:  160 50
# End Point:  180 70
# END POINT:  168
# Prediction on the modified image at point:  16  :  5  is:  8.19877815246582
# STOPS WORKING
# Works!
# Start Point:  0 60
# End Point:  20 80
# END POINT:  20
# Prediction on the modified image at point:  0  :  6  is:  8.103985786437988
# STOPS WORKING
# Works!
# Start Point:  10 60
# End Point:  30 80
# END POINT:  30
# Prediction on the modified image at point:  1  :  6  is:  8.054261207580566
# STOPS WORKING
# Works!
# Start Point:  20 60
# End Point:  40 80
# END POINT:  40
# Prediction on the modified image at point:  2  :  6  is:  7.908823490142822
# STOPS WORKING
# Works!
# Start Point:  30 60
# End Point:  50 80
# END POINT:  50
# Prediction on the modified image at point:  3  :  6  is:  8.141565322875977
# STOPS WORKING
# Works!
# Start Point:  40 60
# End Point:  60 80
# END POINT:  60
# Prediction on the modified image at point:  4  :  6  is:  7.879609107971191
# STOPS WORKING
# Works!
# Start Point:  50 60
# End Point:  70 80
# END POINT:  70
# Prediction on the modified image at point:  5  :  6  is:  7.925207138061523
# STOPS WORKING
# Works!
# Start Point:  60 60
# End Point:  80 80
# END POINT:  80
# Prediction on the modified image at point:  6  :  6  is:  8.231687545776367
# STOPS WORKING
# Works!
# Start Point:  70 60
# End Point:  90 80
# END POINT:  90
# Prediction on the modified image at point:  7  :  6  is:  8.134384155273438
# STOPS WORKING
# Works!
# Start Point:  80 60
# End Point:  100 80
# END POINT:  100
# Prediction on the modified image at point:  8  :  6  is:  8.227202415466309
# STOPS WORKING
# Works!
# Start Point:  90 60
# End Point:  110 80
# END POINT:  110
# Prediction on the modified image at point:  9  :  6  is:  8.10181999206543
# STOPS WORKING
# Works!
# Start Point:  100 60
# End Point:  120 80
# END POINT:  120
# Prediction on the modified image at point:  10  :  6  is:  8.043816566467285
# STOPS WORKING
# Works!
# Start Point:  110 60
# End Point:  130 80
# END POINT:  130
# Prediction on the modified image at point:  11  :  6  is:  8.21342945098877
# STOPS WORKING
# Works!
# Start Point:  120 60
# End Point:  140 80
# END POINT:  140
# Prediction on the modified image at point:  12  :  6  is:  8.091632843017578
# STOPS WORKING
# Works!
# Start Point:  130 60
# End Point:  150 80
# END POINT:  150
# Prediction on the modified image at point:  13  :  6  is:  8.174753189086914
# STOPS WORKING
# Works!
# Start Point:  140 60
# End Point:  160 80
# END POINT:  160
# Prediction on the modified image at point:  14  :  6  is:  8.296143531799316
# STOPS WORKING
# Works!
# Start Point:  150 60
# End Point:  170 80
# END POINT:  168
# Prediction on the modified image at point:  15  :  6  is:  8.250113487243652
# STOPS WORKING
# Works!
# Start Point:  160 60
# End Point:  180 80
# END POINT:  168
# Prediction on the modified image at point:  16  :  6  is:  8.294541358947754
# STOPS WORKING
# Works!
# Start Point:  0 70
# End Point:  20 90
# END POINT:  20
# Prediction on the modified image at point:  0  :  7  is:  8.075528144836426
# STOPS WORKING
# Works!
# Start Point:  10 70
# End Point:  30 90
# END POINT:  30
# Prediction on the modified image at point:  1  :  7  is:  8.10846996307373
# STOPS WORKING
# Works!
# Start Point:  20 70
# End Point:  40 90
# END POINT:  40
# Prediction on the modified image at point:  2  :  7  is:  7.965786933898926
# STOPS WORKING
# Works!
# Start Point:  30 70
# End Point:  50 90
# END POINT:  50
# Prediction on the modified image at point:  3  :  7  is:  8.066344261169434
# STOPS WORKING
# Works!
# Start Point:  40 70
# End Point:  60 90
# END POINT:  60
# Prediction on the modified image at point:  4  :  7  is:  7.740647792816162
# STOPS WORKING
# Works!
# Start Point:  50 70
# End Point:  70 90
# END POINT:  70
# Prediction on the modified image at point:  5  :  7  is:  7.999751091003418
# STOPS WORKING
# Works!
# Start Point:  60 70
# End Point:  80 90
# END POINT:  80
# Prediction on the modified image at point:  6  :  7  is:  7.9963884353637695
# STOPS WORKING
# Works!
# Start Point:  70 70
# End Point:  90 90
# END POINT:  90
# Prediction on the modified image at point:  7  :  7  is:  7.906537055969238
# STOPS WORKING
# Works!
# Start Point:  80 70
# End Point:  100 90
# END POINT:  100
# Prediction on the modified image at point:  8  :  7  is:  7.729753494262695
# STOPS WORKING
# Works!
# Start Point:  90 70
# End Point:  110 90
# END POINT:  110
# Prediction on the modified image at point:  9  :  7  is:  8.050089836120605
# STOPS WORKING
# Works!
# Start Point:  100 70
# End Point:  120 90
# END POINT:  120
# Prediction on the modified image at point:  10  :  7  is:  8.099135398864746
# STOPS WORKING
# Works!
# Start Point:  110 70
# End Point:  130 90
# END POINT:  130
# Prediction on the modified image at point:  11  :  7  is:  8.201664924621582
# STOPS WORKING
# Works!
# Start Point:  120 70
# End Point:  140 90
# END POINT:  140
# Prediction on the modified image at point:  12  :  7  is:  8.212557792663574
# STOPS WORKING
# Works!
# Start Point:  130 70
# End Point:  150 90
# END POINT:  150
# Prediction on the modified image at point:  13  :  7  is:  8.352307319641113
# STOPS WORKING
# Works!
# Start Point:  140 70
# End Point:  160 90
# END POINT:  160
# Prediction on the modified image at point:  14  :  7  is:  8.424864768981934
# STOPS WORKING
# Works!
# Start Point:  150 70
# End Point:  170 90
# END POINT:  168
# Prediction on the modified image at point:  15  :  7  is:  8.264805793762207
# STOPS WORKING
# Works!
# Start Point:  160 70
# End Point:  180 90
# END POINT:  168
# Prediction on the modified image at point:  16  :  7  is:  8.448681831359863
# STOPS WORKING
# Works!
# Start Point:  0 80
# End Point:  20 100
# END POINT:  20
# Prediction on the modified image at point:  0  :  8  is:  8.093539237976074
# STOPS WORKING
# Works!
# Start Point:  10 80
# End Point:  30 100
# END POINT:  30
# Prediction on the modified image at point:  1  :  8  is:  8.177562713623047
# STOPS WORKING
# Works!
# Start Point:  20 80
# End Point:  40 100
# END POINT:  40
# Prediction on the modified image at point:  2  :  8  is:  8.1456937789917
# STOPS WORKING
# Works!
# Start Point:  30 80
# End Point:  50 100
# END POINT:  50
# Prediction on the modified image at point:  3  :  8  is:  7.95538330078125
# STOPS WORKING
# Works!
# Start Point:  40 80
# End Point:  60 100
# END POINT:  60
# Prediction on the modified image at point:  4  :  8  is:  7.951799392700195
# STOPS WORKING
# Works!
# Start Point:  50 80
# End Point:  70 100
# END POINT:  70
# Prediction on the modified image at point:  5  :  8  is:  8.22825813293457
# STOPS WORKING
# Works!
# Start Point:  60 80
# End Point:  80 100
# END POINT:  80
# Prediction on the modified image at point:  6  :  8  is:  7.889259338378906
# STOPS WORKING
# Works!
# Start Point:  70 80
# End Point:  90 100
# END POINT:  90
# Prediction on the modified image at point:  7  :  8  is:  7.509709358215332
# STOPS WORKING
# Works!
# Start Point:  80 80
# End Point:  100 100
# END POINT:  100
# Prediction on the modified image at point:  8  :  8  is:  7.680760383605957
# STOPS WORKING
# Works!
# Start Point:  90 80
# End Point:  110 100
# END POINT:  110
# Prediction on the modified image at point:  9  :  8  is:  7.981037139892578
# STOPS WORKING
# Works!
# Start Point:  100 80
# End Point:  120 100
# END POINT:  120
# Prediction on the modified image at point:  10  :  8  is:  8.051009178161621
# STOPS WORKING
# Works!
# Start Point:  110 80
# End Point:  130 100
# END POINT:  130
# Prediction on the modified image at point:  11  :  8  is:  8.292140007019043
# STOPS WORKING
# Works!
# Start Point:  120 80
# End Point:  140 100
# END POINT:  140
# Prediction on the modified image at point:  12  :  8  is:  8.146845817565918
# STOPS WORKING
# Works!
# Start Point:  130 80
# End Point:  150 100
# END POINT:  150
# Prediction on the modified image at point:  13  :  8  is:  8.360525131225586
# STOPS WORKING
# Works!
# Start Point:  140 80
# End Point:  160 100
# END POINT:  160
# Prediction on the modified image at point:  14  :  8  is:  8.56345272064209
# STOPS WORKING
# Works!
# Start Point:  150 80
# End Point:  170 100
# END POINT:  168
# Prediction on the modified image at point:  15  :  8  is:  8.352715492248535
# STOPS WORKING
# Works!
# Start Point:  160 80
# End Point:  180 100
# END POINT:  168
# Prediction on the modified image at point:  16  :  8  is:  8.317383766174316
# STOPS WORKING
# Works!
# Start Point:  0 90
# End Point:  20 110
# END POINT:  20
# Prediction on the modified image at point:  0  :  9  is:  8.162059783935547
# STOPS WORKING
# Works!
# Start Point:  10 90
# End Point:  30 110
# END POINT:  30
# Prediction on the modified image at point:  1  :  9  is:  8.352754592895508
# STOPS WORKING
# Works!
# Start Point:  20 90
# End Point:  40 110
# END POINT:  40
# Prediction on the modified image at point:  2  :  9  is:  8.433963775634766
# STOPS WORKING
# Works!
# Start Point:  30 90
# End Point:  50 110
# END POINT:  50
# Prediction on the modified image at point:  3  :  9  is:  8.282247543334961
# STOPS WORKING
# Works!
# Start Point:  40 90
# End Point:  60 110
# END POINT:  60
# Prediction on the modified image at point:  4  :  9  is:  8.274298667907715
# STOPS WORKING
# Works!
# Start Point:  50 90
# End Point:  70 110
# END POINT:  70
# Prediction on the modified image at point:  5  :  9  is:  8.449413299560547
# STOPS WORKING
# Works!
# Start Point:  60 90
# End Point:  80 110
# END POINT:  80
# Prediction on the modified image at point:  6  :  9  is:  8.125041007995605
# STOPS WORKING
# Works!
# Start Point:  70 90
# End Point:  90 110
# END POINT:  90
# Prediction on the modified image at point:  7  :  9  is:  7.8319830894470215
# STOPS WORKING
# Works!
# Start Point:  80 90
# End Point:  100 110
# END POINT:  100
# Prediction on the modified image at point:  8  :  9  is:  7.691105842590332
# STOPS WORKING
# Works!
# Start Point:  90 90
# End Point:  110 110
# END POINT:  110
# Prediction on the modified image at point:  9  :  9  is:  7.876834392547607
# STOPS WORKING
# Works!
# Start Point:  100 90
# End Point:  120 110
# END POINT:  120
# Prediction on the modified image at point:  10  :  9  is:  8.038640022277832
# STOPS WORKING
# Works!
# Start Point:  110 90
# End Point:  130 110
# END POINT:  130
# Prediction on the modified image at point:  11  :  9  is:  8.412193298339844
# STOPS WORKING
# Works!
# Start Point:  120 90
# End Point:  140 110
# END POINT:  140
# Prediction on the modified image at point:  12  :  9  is:  8.187098503112793
# STOPS WORKING
# Works!
# Start Point:  130 90
# End Point:  150 110
# END POINT:  150
# Prediction on the modified image at point:  13  :  9  is:  8.346445083618164
# STOPS WORKING
# Works!
# Start Point:  140 90
# End Point:  160 110
# END POINT:  160
# Prediction on the modified image at point:  14  :  9  is:  8.38595199584961
# STOPS WORKING
# Works!
# Start Point:  150 90
# End Point:  170 110
# END POINT:  168
# Prediction on the modified image at point:  15  :  9  is:  8.365955352783203
# STOPS WORKING
# Works!
# Start Point:  160 90
# End Point:  180 110
# END POINT:  168
# Prediction on the modified image at point:  16  :  9  is:  8.371560096740723
# STOPS WORKING
# Works!
# Start Point:  0 100
# End Point:  20 120
# END POINT:  20
# Prediction on the modified image at point:  0  :  10  is:  7.9272260665893555
# STOPS WORKING
# Works!
# Start Point:  10 100
# End Point:  30 120
# END POINT:  30
# Prediction on the modified image at point:  1  :  10  is:  8.25147533416748
# STOPS WORKING
# Works!
# Start Point:  20 100
# End Point:  40 120
# END POINT:  40
# Prediction on the modified image at point:  2  :  10  is:  8.270000457763672
# STOPS WORKING
# Works!
# Start Point:  30 100
# End Point:  50 120
# END POINT:  50
# Prediction on the modified image at point:  3  :  10  is:  8.33318042755127
# STOPS WORKING
# Works!
# Start Point:  40 100
# End Point:  60 120
# END POINT:  60
# Prediction on the modified image at point:  4  :  10  is:  8.219267845153809
# STOPS WORKING
# Works!
# Start Point:  50 100
# End Point:  70 120
# END POINT:  70
# Prediction on the modified image at point:  5  :  10  is:  8.50554370880127
# STOPS WORKING
# Works!
# Start Point:  60 100
# End Point:  80 120
# END POINT:  80
# Prediction on the modified image at point:  6  :  10  is:  8.189618110656738
# STOPS WORKING
# Works!
# Start Point:  70 100
# End Point:  90 120
# END POINT:  90
# Prediction on the modified image at point:  7  :  10  is:  7.945439338684082
# STOPS WORKING
# Works!
# Start Point:  80 100
# End Point:  100 120
# END POINT:  100
# Prediction on the modified image at point:  8  :  10  is:  7.784748077392578
# STOPS WORKING
# Works!
# Start Point:  90 100
# End Point:  110 120
# END POINT:  110
# Prediction on the modified image at point:  9  :  10  is:  8.013585090637207
# STOPS WORKING
# Works!
# Start Point:  100 100
# End Point:  120 120
# END POINT:  120
# Prediction on the modified image at point:  10  :  10  is:  8.32408618927002
# STOPS WORKING
# Works!
# Start Point:  110 100
# End Point:  130 120
# END POINT:  130
# Prediction on the modified image at point:  11  :  10  is:  8.370116233825684
# STOPS WORKING
# Works!
# Start Point:  120 100
# End Point:  140 120
# END POINT:  140
# Prediction on the modified image at point:  12  :  10  is:  8.499161720275879
# STOPS WORKING
# Works!
# Start Point:  130 100
# End Point:  150 120
# END POINT:  150
# Prediction on the modified image at point:  13  :  10  is:  8.31512451171875
# STOPS WORKING
# Works!
# Start Point:  140 100
# End Point:  160 120
# END POINT:  160
# Prediction on the modified image at point:  14  :  10  is:  8.203519821166992
# STOPS WORKING
# Works!
# Start Point:  150 100
# End Point:  170 120
# END POINT:  168
# Prediction on the modified image at point:  15  :  10  is:  8.289047241210938
# STOPS WORKING
# Works!
# Start Point:  160 100
# End Point:  180 120
# END POINT:  168
# Prediction on the modified image at point:  16  :  10  is:  8.47387409210205
# STOPS WORKING
# Works!
# Start Point:  0 110
# End Point:  20 130
# END POINT:  20
# Prediction on the modified image at point:  0  :  11  is:  8.05156421661377
# STOPS WORKING
# Works!
# Start Point:  10 110
# End Point:  30 130
# END POINT:  30
# Prediction on the modified image at point:  1  :  11  is:  8.233536720275879
# STOPS WORKING
# Works!
# Start Point:  20 110
# End Point:  40 130
# END POINT:  40
# Prediction on the modified image at point:  2  :  11  is:  8.381193161010742
# STOPS WORKING
# Works!
# Start Point:  30 110
# End Point:  50 130
# END POINT:  50
# Prediction on the modified image at point:  3  :  11  is:  8.280278205871582
# STOPS WORKING
# Works!
# Start Point:  40 110
# End Point:  60 130
# END POINT:  60
# Prediction on the modified image at point:  4  :  11  is:  8.263711929321289
# STOPS WORKING
# Works!
# Start Point:  50 110
# End Point:  70 130
# END POINT:  70
# Prediction on the modified image at point:  5  :  11  is:  8.427916526794434
# STOPS WORKING
# Works!
# Start Point:  60 110
# End Point:  80 130
# END POINT:  80
# Prediction on the modified image at point:  6  :  11  is:  8.371064186096191
# STOPS WORKING
# Works!
# Start Point:  70 110
# End Point:  90 130
# END POINT:  90
# Prediction on the modified image at point:  7  :  11  is:  8.091660499572754
# STOPS WORKING
# Works!
# Start Point:  80 110
# End Point:  100 130
# END POINT:  100
# Prediction on the modified image at point:  8  :  11  is:  7.8516950607299805
# STOPS WORKING
# Works!
# Start Point:  90 110
# End Point:  110 130
# END POINT:  110
# Prediction on the modified image at point:  9  :  11  is:  8.073948860168457
# STOPS WORKING
# Works!
# Start Point:  100 110
# End Point:  120 130
# END POINT:  120
# Prediction on the modified image at point:  10  :  11  is:  8.347322463989258
# STOPS WORKING
# Works!
# Start Point:  110 110
# End Point:  130 130
# END POINT:  130
# Prediction on the modified image at point:  11  :  11  is:  8.451054573059082
# STOPS WORKING
# Works!
# Start Point:  120 110
# End Point:  140 130
# END POINT:  140
# Prediction on the modified image at point:  12  :  11  is:  8.48600959777832
# STOPS WORKING
# Works!
# Start Point:  130 110
# End Point:  150 130
# END POINT:  150
# Prediction on the modified image at point:  13  :  11  is:  8.507649421691895
# STOPS WORKING
# Works!
# Start Point:  140 110
# End Point:  160 130
# END POINT:  160
# Prediction on the modified image at point:  14  :  11  is:  8.276008605957031
# STOPS WORKING
# Works!
# Start Point:  150 110
# End Point:  170 130
# END POINT:  168
# Prediction on the modified image at point:  15  :  11  is:  8.373637199401855
# STOPS WORKING
# Works!
# Start Point:  160 110
# End Point:  180 130
# END POINT:  168
# Prediction on the modified image at point:  16  :  11  is:  8.383733749389648
# STOPS WORKING
# Works!
# Start Point:  0 120
# End Point:  20 140
# END POINT:  20
# Prediction on the modified image at point:  0  :  12  is:  8.17883014678955
# STOPS WORKING
# Works!
# Start Point:  10 120
# End Point:  30 140
# END POINT:  30
# Prediction on the modified image at point:  1  :  12  is:  8.260108947753906
# STOPS WORKING
# Works!
# Start Point:  20 120
# End Point:  40 140
# END POINT:  40
# Prediction on the modified image at point:  2  :  12  is:  8.42618179321289
# STOPS WORKING
# Works!
# Start Point:  30 120
# End Point:  50 140
# END POINT:  50
# Prediction on the modified image at point:  3  :  12  is:  8.525788307189941
# STOPS WORKING
# Works!
# Start Point:  40 120
# End Point:  60 140
# END POINT:  60
# Prediction on the modified image at point:  4  :  12  is:  8.425490379333496
# STOPS WORKING
# Works!
# Start Point:  50 120
# End Point:  70 140
# END POINT:  70
# Prediction on the modified image at point:  5  :  12  is:  8.418253898620605
# STOPS WORKING
# Works!
# Start Point:  60 120
# End Point:  80 140
# END POINT:  80
# Prediction on the modified image at point:  6  :  12  is:  8.285611152648926
# STOPS WORKING
# Works!
# Start Point:  70 120
# End Point:  90 140
# END POINT:  90
# Prediction on the modified image at point:  7  :  12  is:  8.181114196777344
# STOPS WORKING
# Works!
# Start Point:  80 120
# End Point:  100 140
# END POINT:  100
# Prediction on the modified image at point:  8  :  12  is:  7.989278793334961
# STOPS WORKING
# Works!
# Start Point:  90 120
# End Point:  110 140
# END POINT:  110
# Prediction on the modified image at point:  9  :  12  is:  8.171408653259277
# STOPS WORKING
# Works!
# Start Point:  100 120
# End Point:  120 140
# END POINT:  120
# Prediction on the modified image at point:  10  :  12  is:  8.263648986816406
# STOPS WORKING
# Works!
# Start Point:  110 120
# End Point:  130 140
# END POINT:  130
# Prediction on the modified image at point:  11  :  12  is:  8.412687301635742
# STOPS WORKING
# Works!
# Start Point:  120 120
# End Point:  140 140
# END POINT:  140
# Prediction on the modified image at point:  12  :  12  is:  8.366413116455078
# STOPS WORKING
# Works!
# Start Point:  130 120
# End Point:  150 140
# END POINT:  150
# Prediction on the modified image at point:  13  :  12  is:  8.195622444152832
# STOPS WORKING
# Works!
# Start Point:  140 120
# End Point:  160 140
# END POINT:  160
# Prediction on the modified image at point:  14  :  12  is:  8.31573486328125
# STOPS WORKING
# Works!
# Start Point:  150 120
# End Point:  170 140
# END POINT:  168
# Prediction on the modified image at point:  15  :  12  is:  8.315312385559082
# STOPS WORKING
# Works!
# Start Point:  160 120
# End Point:  180 140
# END POINT:  168
# Prediction on the modified image at point:  16  :  12  is:  8.375040054321289
# STOPS WORKING
# Works!
# Start Point:  0 130
# End Point:  20 150
# END POINT:  20
# Prediction on the modified image at point:  0  :  13  is:  8.286099433898926
# STOPS WORKING
# Works!
# Start Point:  10 130
# End Point:  30 150
# END POINT:  30
# Prediction on the modified image at point:  1  :  13  is:  8.315533638000488
# STOPS WORKING
# Works!
# Start Point:  20 130
# End Point:  40 150
# END POINT:  40
# Prediction on the modified image at point:  2  :  13  is:  8.250985145568848
# STOPS WORKING
# Works!
# Start Point:  30 130
# End Point:  50 150
# END POINT:  50
# Prediction on the modified image at point:  3  :  13  is:  8.402482986450195
# STOPS WORKING
# Works!
# Start Point:  40 130
# End Point:  60 150
# END POINT:  60
# Prediction on the modified image at point:  4  :  13  is:  8.469512939453125
# STOPS WORKING
# Works!
# Start Point:  50 130
# End Point:  70 150
# END POINT:  70
# Prediction on the modified image at point:  5  :  13  is:  8.315598487854004
# STOPS WORKING
# Works!
# Start Point:  60 130
# End Point:  80 150
# END POINT:  80
# Prediction on the modified image at point:  6  :  13  is:  8.26608943939209
# STOPS WORKING
# Works!
# Start Point:  70 130
# End Point:  90 150
# END POINT:  90
# Prediction on the modified image at point:  7  :  13  is:  8.122797966003418
# STOPS WORKING
# Works!
# Start Point:  80 130
# End Point:  100 150
# END POINT:  100
# Prediction on the modified image at point:  8  :  13  is:  8.1287202835083
# STOPS WORKING
# Works!
# Start Point:  90 130
# End Point:  110 150
# END POINT:  110
# Prediction on the modified image at point:  9  :  13  is:  8.10356330871582
# STOPS WORKING
# Works!
# Start Point:  100 130
# End Point:  120 150
# END POINT:  120
# Prediction on the modified image at point:  10  :  13  is:  8.234221458435059
# STOPS WORKING
# Works!
# Start Point:  110 130
# End Point:  130 150
# END POINT:  130
# Prediction on the modified image at point:  11  :  13  is:  8.338704109191895
# STOPS WORKING
# Works!
# Start Point:  120 130
# End Point:  140 150
# END POINT:  140
# Prediction on the modified image at point:  12  :  13  is:  8.485997200012207
# STOPS WORKING
# Works!
# Start Point:  130 130
# End Point:  150 150
# END POINT:  150
# Prediction on the modified image at point:  13  :  13  is:  8.166775703430176
# STOPS WORKING
# Works!
# Start Point:  140 130
# End Point:  160 150
# END POINT:  160
# Prediction on the modified image at point:  14  :  13  is:  8.15722942352295
# STOPS WORKING
# Works!
# Start Point:  150 130
# End Point:  170 150
# END POINT:  168
# Prediction on the modified image at point:  15  :  13  is:  8.233725547790527
# STOPS WORKING
# Works!
# Start Point:  160 130
# End Point:  180 150
# END POINT:  168
# Prediction on the modified image at point:  16  :  13  is:  8.33594799041748
# STOPS WORKING
# Works!
# Start Point:  0 140
# End Point:  20 160
# END POINT:  20
# Prediction on the modified image at point:  0  :  14  is:  8.29399585723877
# STOPS WORKING
# Works!
# Start Point:  10 140
# End Point:  30 160
# END POINT:  30
# Prediction on the modified image at point:  1  :  14  is:  8.288444519042969
# STOPS WORKING
# Works!
# Start Point:  20 140
# End Point:  40 160
# END POINT:  40
# Prediction on the modified image at point:  2  :  14  is:  8.262866020202637
# STOPS WORKING
# Works!
# Start Point:  30 140
# End Point:  50 160
# END POINT:  50
# Prediction on the modified image at point:  3  :  14  is:  8.268876075744629
# STOPS WORKING
# Works!
# Start Point:  40 140
# End Point:  60 160
# END POINT:  60
# Prediction on the modified image at point:  4  :  14  is:  8.42014217376709
# STOPS WORKING
# Works!
# Start Point:  50 140
# End Point:  70 160
# END POINT:  70
# Prediction on the modified image at point:  5  :  14  is:  8.14471435546875
# STOPS WORKING
# Works!
# Start Point:  60 140
# End Point:  80 160
# END POINT:  80
# Prediction on the modified image at point:  6  :  14  is:  8.157886505126953
# STOPS WORKING
# Works!
# Start Point:  70 140
# End Point:  90 160
# END POINT:  90
# Prediction on the modified image at point:  7  :  14  is:  8.01911449432373
# STOPS WORKING
# Works!
# Start Point:  80 140
# End Point:  100 160
# END POINT:  100
# Prediction on the modified image at point:  8  :  14  is:  8.031306266784668
# STOPS WORKING
# Works!
# Start Point:  90 140
# End Point:  110 160
# END POINT:  110
# Prediction on the modified image at point:  9  :  14  is:  8.016322135925293
# STOPS WORKING
# Works!
# Start Point:  100 140
# End Point:  120 160
# END POINT:  120
# Prediction on the modified image at point:  10  :  14  is:  7.999504089355469
# STOPS WORKING
# Works!
# Start Point:  110 140
# End Point:  130 160
# END POINT:  130
# Prediction on the modified image at point:  11  :  14  is:  8.29565715789795
# STOPS WORKING
# Works!
# Start Point:  120 140
# End Point:  140 160
# END POINT:  140
# Prediction on the modified image at point:  12  :  14  is:  8.27059268951416
# STOPS WORKING
# Works!
# Start Point:  130 140
# End Point:  150 160
# END POINT:  150
# Prediction on the modified image at point:  13  :  14  is:  8.12232494354248
# STOPS WORKING
# Works!
# Start Point:  140 140
# End Point:  160 160
# END POINT:  160
# Prediction on the modified image at point:  14  :  14  is:  8.094736099243164
# STOPS WORKING
# Works!
# Start Point:  150 140
# End Point:  170 160
# END POINT:  168
# Prediction on the modified image at point:  15  :  14  is:  8.220787048339844
# STOPS WORKING
# Works!
# Start Point:  160 140
# End Point:  180 160
# END POINT:  168
# Prediction on the modified image at point:  16  :  14  is:  8.31690788269043
# STOPS WORKING
# Works!
# Start Point:  0 150
# End Point:  20 170
# END POINT:  20
# Prediction on the modified image at point:  0  :  15  is:  8.241828918457031
# STOPS WORKING
# Works!
# Start Point:  10 150
# End Point:  30 170
# END POINT:  30
# Prediction on the modified image at point:  1  :  15  is:  8.274591445922852
# STOPS WORKING
# Works!
# Start Point:  20 150
# End Point:  40 170
# END POINT:  40
# Prediction on the modified image at point:  2  :  15  is:  8.329268455505371
# STOPS WORKING
# Works!
# Start Point:  30 150
# End Point:  50 170
# END POINT:  50
# Prediction on the modified image at point:  3  :  15  is:  8.279009819030762
# STOPS WORKING
# Works!
# Start Point:  40 150
# End Point:  60 170
# END POINT:  60
# Prediction on the modified image at point:  4  :  15  is:  8.435208320617676
# STOPS WORKING
# Works!
# Start Point:  50 150
# End Point:  70 170
# END POINT:  70
# Prediction on the modified image at point:  5  :  15  is:  8.093709945678711
# STOPS WORKING
# Works!
# Start Point:  60 150
# End Point:  80 170
# END POINT:  80
# Prediction on the modified image at point:  6  :  15  is:  7.8573317527771
# STOPS WORKING
# Works!
# Start Point:  70 150
# End Point:  90 170
# END POINT:  90
# Prediction on the modified image at point:  7  :  15  is:  8.050268173217773
# STOPS WORKING
# Works!
# Start Point:  80 150
# End Point:  100 170
# END POINT:  100
# Prediction on the modified image at point:  8  :  15  is:  8.182978630065918
# STOPS WORKING
# Works!
# Start Point:  90 150
# End Point:  110 170
# END POINT:  110
# Prediction on the modified image at point:  9  :  15  is:  8.209242820739746
# STOPS WORKING
# Works!
# Start Point:  100 150
# End Point:  120 170
# END POINT:  120
# Prediction on the modified image at point:  10  :  15  is:  8.281661033630371
# STOPS WORKING
# Works!
# Start Point:  110 150
# End Point:  130 170
# END POINT:  130
# Prediction on the modified image at point:  11  :  15  is:  8.238049507141113
# STOPS WORKING
# Works!
# Start Point:  120 150
# End Point:  140 170
# END POINT:  140
# Prediction on the modified image at point:  12  :  15  is:  8.173026084899902
# STOPS WORKING
# Works!
# Start Point:  130 150
# End Point:  150 170
# END POINT:  150
# Prediction on the modified image at point:  13  :  15  is:  8.153009414672852
# STOPS WORKING
# Works!
# Start Point:  140 150
# End Point:  160 170
# END POINT:  160
# Prediction on the modified image at point:  14  :  15  is:  8.273187637329102
# STOPS WORKING
# Works!
# Start Point:  150 150
# End Point:  170 170
# END POINT:  168
# Prediction on the modified image at point:  15  :  15  is:  8.276679992675781
# STOPS WORKING
# Works!
# Start Point:  160 150
# End Point:  180 170
# END POINT:  168
# Prediction on the modified image at point:  16  :  15  is:  8.290209770202637
# STOPS WORKING
# Works!
# Start Point:  0 160
# End Point:  20 180
# END POINT:  20
# Prediction on the modified image at point:  0  :  16  is:  8.279011726379395
# STOPS WORKING
# Works!
# Start Point:  10 160
# End Point:  30 180
# END POINT:  30
# Prediction on the modified image at point:  1  :  16  is:  8.19273853302002
# STOPS WORKING
# Works!
# Start Point:  20 160
# End Point:  40 180
# END POINT:  40
# Prediction on the modified image at point:  2  :  16  is:  8.105528831481934
# STOPS WORKING
# Works!
# Start Point:  30 160
# End Point:  50 180
# END POINT:  50
# Prediction on the modified image at point:  3  :  16  is:  8.224775314331055
# STOPS WORKING
# Works!
# Start Point:  40 160
# End Point:  60 180
# END POINT:  60
# Prediction on the modified image at point:  4  :  16  is:  8.136723518371582
# STOPS WORKING
# Works!
# Start Point:  50 160
# End Point:  70 180
# END POINT:  70
# Prediction on the modified image at point:  5  :  16  is:  7.941399097442627
# STOPS WORKING
# Works!
# Start Point:  60 160
# End Point:  80 180
# END POINT:  80
# Prediction on the modified image at point:  6  :  16  is:  7.903464317321777
# STOPS WORKING
# Works!
# Start Point:  70 160
# End Point:  90 180
# END POINT:  90
# Prediction on the modified image at point:  7  :  16  is:  8.117959022521973
# STOPS WORKING
# Works!
# Start Point:  80 160
# End Point:  100 180
# END POINT:  100
# Prediction on the modified image at point:  8  :  16  is:  8.033464431762695
# STOPS WORKING
# Works!
# Start Point:  90 160
# End Point:  110 180
# END POINT:  110
# Prediction on the modified image at point:  9  :  16  is:  8.204009056091309
# STOPS WORKING
# Works!
# Start Point:  100 160
# End Point:  120 180
# END POINT:  120
# Prediction on the modified image at point:  10  :  16  is:  8.271987915039062
# STOPS WORKING
# Works!
# Start Point:  110 160
# End Point:  130 180
# END POINT:  130
# Prediction on the modified image at point:  11  :  16  is:  8.190074920654297
# STOPS WORKING
# Works!
# Start Point:  120 160
# End Point:  140 180
# END POINT:  140
# Prediction on the modified image at point:  12  :  16  is:  8.103635787963867
# STOPS WORKING
# Works!
# Start Point:  130 160
# End Point:  150 180
# END POINT:  150
# Prediction on the modified image at point:  13  :  16  is:  8.302017211914062
# STOPS WORKING
# Works!
# Start Point:  140 160
# End Point:  160 180
# END POINT:  160
# Prediction on the modified image at point:  14  :  16  is:  8.328943252563477
# STOPS WORKING
# Works!
# Start Point:  150 160
# End Point:  170 180
# END POINT:  168
# Prediction on the modified image at point:  15  :  16  is:  8.361227989196777
# STOPS WORKING
# Works!
# Start Point:  160 160
# End Point:  180 180
# END POINT:  168
# Prediction on the modified image at point:  16  :  16  is:  8.352702140808105
# STOPS WORKING
# Works!
# Start Point:  0 170
# End Point:  20 190
# END POINT:  20
# Prediction on the modified image at point:  0  :  17  is:  8.238505363464355
# STOPS WORKING
# Works!
# Start Point:  10 170
# End Point:  30 190
# END POINT:  30
# Prediction on the modified image at point:  1  :  17  is:  8.157777786254883
# STOPS WORKING
# Works!
# Start Point:  20 170
# End Point:  40 190
# END POINT:  40
# Prediction on the modified image at point:  2  :  17  is:  8.053847312927246
# STOPS WORKING
# Works!
# Start Point:  30 170
# End Point:  50 190
# END POINT:  50
# Prediction on the modified image at point:  3  :  17  is:  8.297051429748535
# STOPS WORKING
# Works!
# Start Point:  40 170
# End Point:  60 190
# END POINT:  60
# Prediction on the modified image at point:  4  :  17  is:  8.204230308532715
# STOPS WORKING
# Works!
# Start Point:  50 170
# End Point:  70 190
# END POINT:  70
# Prediction on the modified image at point:  5  :  17  is:  8.096449851989746
# STOPS WORKING
# Works!
# Start Point:  60 170
# End Point:  80 190
# END POINT:  80
# Prediction on the modified image at point:  6  :  17  is:  7.947436332702637
# STOPS WORKING
# Works!
# Start Point:  70 170
# End Point:  90 190
# END POINT:  90
# Prediction on the modified image at point:  7  :  17  is:  8.219300270080566
# STOPS WORKING
# Works!
# Start Point:  80 170
# End Point:  100 190
# END POINT:  100
# Prediction on the modified image at point:  8  :  17  is:  8.11282730102539
# STOPS WORKING
# Works!
# Start Point:  90 170
# End Point:  110 190
# END POINT:  110
# Prediction on the modified image at point:  9  :  17  is:  8.181536674499512
# STOPS WORKING
# Works!
# Start Point:  100 170
# End Point:  120 190
# END POINT:  120
# Prediction on the modified image at point:  10  :  17  is:  8.338436126708984
# STOPS WORKING
# Works!
# Start Point:  110 170
# End Point:  130 190
# END POINT:  130
# Prediction on the modified image at point:  11  :  17  is:  8.300236701965332
# STOPS WORKING
# Works!
# Start Point:  120 170
# End Point:  140 190
# END POINT:  140
# Prediction on the modified image at point:  12  :  17  is:  8.263031959533691
# STOPS WORKING
# Works!
# Start Point:  130 170
# End Point:  150 190
# END POINT:  150
# Prediction on the modified image at point:  13  :  17  is:  8.354392051696777
# STOPS WORKING
# Works!
# Start Point:  140 170
# End Point:  160 190
# END POINT:  160
# Prediction on the modified image at point:  14  :  17  is:  8.33605670928955
# STOPS WORKING
# Works!
# Start Point:  150 170
# End Point:  170 190
# END POINT:  168
# Prediction on the modified image at point:  15  :  17  is:  8.32497501373291
# STOPS WORKING
# Works!
# Start Point:  160 170
# End Point:  180 190
# END POINT:  168
# Prediction on the modified image at point:  16  :  17  is:  8.378273963928223
# STOPS WORKING
# Works!
# Start Point:  0 180
# End Point:  20 200
# END POINT:  20
# Prediction on the modified image at point:  0  :  18  is:  8.243293762207031
# STOPS WORKING
# Works!
# Start Point:  10 180
# End Point:  30 200
# END POINT:  30
# Prediction on the modified image at point:  1  :  18  is:  8.151028633117676
# STOPS WORKING
# Works!
# Start Point:  20 180
# End Point:  40 200
# END POINT:  40
# Prediction on the modified image at point:  2  :  18  is:  8.08726978302002
# STOPS WORKING
# Works!
# Start Point:  30 180
# End Point:  50 200
# END POINT:  50
# Prediction on the modified image at point:  3  :  18  is:  8.146997451782227
# STOPS WORKING
# Works!
# Start Point:  40 180
# End Point:  60 200
# END POINT:  60
# Prediction on the modified image at point:  4  :  18  is:  8.206511497497559
# STOPS WORKING
# Works!
# Start Point:  50 180
# End Point:  70 200
# END POINT:  70
# Prediction on the modified image at point:  5  :  18  is:  8.008444786071777
# STOPS WORKING
# Works!
# Start Point:  60 180
# End Point:  80 200
# END POINT:  80
# Prediction on the modified image at point:  6  :  18  is:  8.079791069030762
# STOPS WORKING
# Works!
# Start Point:  70 180
# End Point:  90 200
# END POINT:  90
# Prediction on the modified image at point:  7  :  18  is:  8.006427764892578
# STOPS WORKING
# Works!
# Start Point:  80 180
# End Point:  100 200
# END POINT:  100
# Prediction on the modified image at point:  8  :  18  is:  8.036001205444336
# STOPS WORKING
# Works!
# Start Point:  90 180
# End Point:  110 200
# END POINT:  110
# Prediction on the modified image at point:  9  :  18  is:  8.188491821289062
# STOPS WORKING
# Works!
# Start Point:  100 180
# End Point:  120 200
# END POINT:  120
# Prediction on the modified image at point:  10  :  18  is:  8.165453910827637
# STOPS WORKING
# Works!
# Start Point:  110 180
# End Point:  130 200
# END POINT:  130
# Prediction on the modified image at point:  11  :  18  is:  8.191747665405273
# STOPS WORKING
# Works!
# Start Point:  120 180
# End Point:  140 200
# END POINT:  140
# Prediction on the modified image at point:  12  :  18  is:  8.271857261657715
# STOPS WORKING
# Works!
# Start Point:  130 180
# End Point:  150 200
# END POINT:  150
# Prediction on the modified image at point:  13  :  18  is:  8.32949161529541
# STOPS WORKING
# Works!
# Start Point:  140 180
# End Point:  160 200
# END POINT:  160
# Prediction on the modified image at point:  14  :  18  is:  8.359993934631348
# STOPS WORKING
# Works!
# Start Point:  150 180
# End Point:  170 200
# END POINT:  168
# Prediction on the modified image at point:  15  :  18  is:  8.306999206542969
# STOPS WORKING
# Works!
# Start Point:  160 180
# End Point:  180 200
# END POINT:  168
# Prediction on the modified image at point:  16  :  18  is:  8.308521270751953
# STOPS WORKING
# Works!
# Start Point:  0 190
# End Point:  20 210
# END POINT:  20
# Prediction on the modified image at point:  0  :  19  is:  8.287249565124512
# STOPS WORKING
# Works!
# Start Point:  10 190
# End Point:  30 210
# END POINT:  30
# Prediction on the modified image at point:  1  :  19  is:  8.226465225219727
# STOPS WORKING
# Works!
# Start Point:  20 190
# End Point:  40 210
# END POINT:  40
# Prediction on the modified image at point:  2  :  19  is:  8.137001991271973
# STOPS WORKING
# Works!
# Start Point:  30 190
# End Point:  50 210
# END POINT:  50
# Prediction on the modified image at point:  3  :  19  is:  8.15042781829834
# STOPS WORKING
# Works!
# Start Point:  40 190
# End Point:  60 210
# END POINT:  60
# Prediction on the modified image at point:  4  :  19  is:  8.19387435913086
# STOPS WORKING
# Works!
# Start Point:  50 190
# End Point:  70 210
# END POINT:  70
# Prediction on the modified image at point:  5  :  19  is:  8.15352725982666
# STOPS WORKING
# Works!
# Start Point:  60 190
# End Point:  80 210
# END POINT:  80
# Prediction on the modified image at point:  6  :  19  is:  8.168456077575684
# STOPS WORKING
# Works!
# Start Point:  70 190
# End Point:  90 210
# END POINT:  90
# Prediction on the modified image at point:  7  :  19  is:  8.197646141052246
# STOPS WORKING
# Works!
# Start Point:  80 190
# End Point:  100 210
# END POINT:  100
# Prediction on the modified image at point:  8  :  19  is:  8.185750961303711
# STOPS WORKING
# Works!
# Start Point:  90 190
# End Point:  110 210
# END POINT:  110
# Prediction on the modified image at point:  9  :  19  is:  8.145722389221191
# STOPS WORKING
# Works!
# Start Point:  100 190
# End Point:  120 210
# END POINT:  120
# Prediction on the modified image at point:  10  :  19  is:  8.203019142150879
# STOPS WORKING
# Works!
# Start Point:  110 190
# End Point:  130 210
# END POINT:  130
# Prediction on the modified image at point:  11  :  19  is:  8.299383163452148
# STOPS WORKING
# Works!
# Start Point:  120 190
# End Point:  140 210
# END POINT:  140
# Prediction on the modified image at point:  12  :  19  is:  8.31807804107666
# STOPS WORKING
# Works!
# Start Point:  130 190
# End Point:  150 210
# END POINT:  150
# Prediction on the modified image at point:  13  :  19  is:  8.391398429870605
# STOPS WORKING
# Works!
# Start Point:  140 190
# End Point:  160 210
# END POINT:  160
# Prediction on the modified image at point:  14  :  19  is:  8.383670806884766
# STOPS WORKING
# Works!
# Start Point:  150 190
# End Point:  170 210
# END POINT:  168
# Prediction on the modified image at point:  15  :  19  is:  8.349980354309082
# STOPS WORKING
# Works!
# Start Point:  160 190
# End Point:  180 210
# END POINT:  168
# Prediction on the modified image at point:  16  :  19  is:  8.325560569763184
# STOPS WORKING
# Works!
# Start Point:  0 200
# End Point:  20 220
# END POINT:  20
# Prediction on the modified image at point:  0  :  20  is:  8.262481689453125
# STOPS WORKING
# Works!
# Start Point:  10 200
# End Point:  30 220
# END POINT:  30
# Prediction on the modified image at point:  1  :  20  is:  8.249859809875488
# STOPS WORKING
# Works!
# Start Point:  20 200
# End Point:  40 220
# END POINT:  40
# Prediction on the modified image at point:  2  :  20  is:  8.208117485046387
# STOPS WORKING
# Works!
# Start Point:  30 200
# End Point:  50 220
# END POINT:  50
# Prediction on the modified image at point:  3  :  20  is:  8.176019668579102
# STOPS WORKING
# Works!
# Start Point:  40 200
# End Point:  60 220
# END POINT:  60
# Prediction on the modified image at point:  4  :  20  is:  8.08420467376709
# STOPS WORKING
# Works!
# Start Point:  50 200
# End Point:  70 220
# END POINT:  70
# Prediction on the modified image at point:  5  :  20  is:  8.035128593444824
# STOPS WORKING
# Works!
# Start Point:  60 200
# End Point:  80 220
# END POINT:  80
# Prediction on the modified image at point:  6  :  20  is:  8.027857780456543
# STOPS WORKING
# Works!
# Start Point:  70 200
# End Point:  90 220
# END POINT:  90
# Prediction on the modified image at point:  7  :  20  is:  8.114413261413574
# STOPS WORKING
# Works!
# Start Point:  80 200
# End Point:  100 220
# END POINT:  100
# Prediction on the modified image at point:  8  :  20  is:  8.148683547973633
# STOPS WORKING
# Works!
# Start Point:  90 200
# End Point:  110 220
# END POINT:  110
# Prediction on the modified image at point:  9  :  20  is:  8.14880657196045
# STOPS WORKING
# Works!
# Start Point:  100 200
# End Point:  120 220
# END POINT:  120
# Prediction on the modified image at point:  10  :  20  is:  8.210419654846191
# STOPS WORKING
# Works!
# Start Point:  110 200
# End Point:  130 220
# END POINT:  130
# Prediction on the modified image at point:  11  :  20  is:  8.222023963928223
# STOPS WORKING
# Works!
# Start Point:  120 200
# End Point:  140 220
# END POINT:  140
# Prediction on the modified image at point:  12  :  20  is:  8.32580280303955
# STOPS WORKING
# Works!
# Start Point:  130 200
# End Point:  150 220
# END POINT:  150
# Prediction on the modified image at point:  13  :  20  is:  8.356961250305176
# STOPS WORKING
# Works!
# Start Point:  140 200
# End Point:  160 220
# END POINT:  160
# Prediction on the modified image at point:  14  :  20  is:  8.325335502624512
# STOPS WORKING
# Works!
# Start Point:  150 200
# End Point:  170 220
# END POINT:  168
# Prediction on the modified image at point:  15  :  20  is:  8.356446266174316
# STOPS WORKING
# Works!
# Start Point:  160 200
# End Point:  180 220
# END POINT:  168
# Prediction on the modified image at point:  16  :  20  is:  8.285429954528809
# STOPS WORKING
# Works!
# Start Point:  0 210
# End Point:  20 230
# END POINT:  20
# Prediction on the modified image at point:  0  :  21  is:  8.276164054870605
# STOPS WORKING
# Works!
# Start Point:  10 210
# End Point:  30 230
# END POINT:  30
# Prediction on the modified image at point:  1  :  21  is:  8.233534812927246
# STOPS WORKING
# Works!
# Start Point:  20 210
# End Point:  40 230
# END POINT:  40
# Prediction on the modified image at point:  2  :  21  is:  8.158495903015137
# STOPS WORKING
# Works!
# Start Point:  30 210
# End Point:  50 230
# END POINT:  50
# Prediction on the modified image at point:  3  :  21  is:  8.15209674835205
# STOPS WORKING
# Works!
# Start Point:  40 210
# End Point:  60 230
# END POINT:  60
# Prediction on the modified image at point:  4  :  21  is:  8.10867691040039
# STOPS WORKING
# Works!
# Start Point:  50 210
# End Point:  70 230
# END POINT:  70
# Prediction on the modified image at point:  5  :  21  is:  8.224427223205566
# STOPS WORKING
# Works!
# Start Point:  60 210
# End Point:  80 230
# END POINT:  80
# Prediction on the modified image at point:  6  :  21  is:  8.187448501586914
# STOPS WORKING
# Works!
# Start Point:  70 210
# End Point:  90 230
# END POINT:  90
# Prediction on the modified image at point:  7  :  21  is:  8.230058670043945
# STOPS WORKING
# Works!
# Start Point:  80 210
# End Point:  100 230
# END POINT:  100
# Prediction on the modified image at point:  8  :  21  is:  8.213929176330566
# STOPS WORKING
# Works!
# Start Point:  90 210
# End Point:  110 230
# END POINT:  110
# Prediction on the modified image at point:  9  :  21  is:  8.255657196044922
# STOPS WORKING
# Works!
# Start Point:  100 210
# End Point:  120 230
# END POINT:  120
# Prediction on the modified image at point:  10  :  21  is:  8.258548736572266
# STOPS WORKING
# Works!
# Start Point:  110 210
# End Point:  130 230
# END POINT:  130
# Prediction on the modified image at point:  11  :  21  is:  8.266216278076172
# STOPS WORKING
# Works!
# Start Point:  120 210
# End Point:  140 230
# END POINT:  140
# Prediction on the modified image at point:  12  :  21  is:  8.283557891845703
# STOPS WORKING
# Works!
# Start Point:  130 210
# End Point:  150 230
# END POINT:  150
# Prediction on the modified image at point:  13  :  21  is:  8.385765075683594
# STOPS WORKING
# Works!
# Start Point:  140 210
# End Point:  160 230
# END POINT:  160
# Prediction on the modified image at point:  14  :  21  is:  8.42056941986084
# STOPS WORKING
# Works!
# Start Point:  150 210
# End Point:  170 230
# END POINT:  168
# Prediction on the modified image at point:  15  :  21  is:  8.463418006896973
# STOPS WORKING
# Works!
# Start Point:  160 210
# End Point:  180 230
# END POINT:  168
# Prediction on the modified image at point:  16  :  21  is:  8.371954917907715
# STOPS WORKING
# Works!
# Start Point:  0 220
# End Point:  20 240
# END POINT:  20
# Prediction on the modified image at point:  0  :  22  is:  8.29903507232666
# STOPS WORKING
# Works!
# Start Point:  10 220
# End Point:  30 240
# END POINT:  30
# Prediction on the modified image at point:  1  :  22  is:  8.3175687789917
# STOPS WORKING
# Works!
# Start Point:  20 220
# End Point:  40 240
# END POINT:  40
# Prediction on the modified image at point:  2  :  22  is:  8.234845161437988
# STOPS WORKING
# Works!
# Start Point:  30 220
# End Point:  50 240
# END POINT:  50
# Prediction on the modified image at point:  3  :  22  is:  8.208671569824219
# STOPS WORKING
# Works!
# Start Point:  40 220
# End Point:  60 240
# END POINT:  60
# Prediction on the modified image at point:  4  :  22  is:  8.24462604522705
# STOPS WORKING
# Works!
# Start Point:  50 220
# End Point:  70 240
# END POINT:  70
# Prediction on the modified image at point:  5  :  22  is:  8.281228065490723
# STOPS WORKING
# Works!
# Start Point:  60 220
# End Point:  80 240
# END POINT:  80
# Prediction on the modified image at point:  6  :  22  is:  8.271985054016113
# STOPS WORKING
# Works!
# Start Point:  70 220
# End Point:  90 240
# END POINT:  90
# Prediction on the modified image at point:  7  :  22  is:  8.293210983276367
# STOPS WORKING
# Works!
# Start Point:  80 220
# End Point:  100 240
# END POINT:  100
# Prediction on the modified image at point:  8  :  22  is:  8.278353691101074
# STOPS WORKING
# Works!
# Start Point:  90 220
# End Point:  110 240
# END POINT:  110
# Prediction on the modified image at point:  9  :  22  is:  8.249591827392578
# STOPS WORKING
# Works!
# Start Point:  100 220
# End Point:  120 240
# END POINT:  120
# Prediction on the modified image at point:  10  :  22  is:  8.256185531616211
# STOPS WORKING
# Works!
# Start Point:  110 220
# End Point:  130 240
# END POINT:  130
# Prediction on the modified image at point:  11  :  22  is:  8.296710014343262
# STOPS WORKING
# Works!
# Start Point:  120 220
# End Point:  140 240
# END POINT:  140
# Prediction on the modified image at point:  12  :  22  is:  8.295860290527344
# STOPS WORKING
# Works!
# Start Point:  130 220
# End Point:  150 240
# END POINT:  150
# Prediction on the modified image at point:  13  :  22  is:  8.339629173278809
# STOPS WORKING
# Works!
# Start Point:  140 220
# End Point:  160 240
# END POINT:  160
# Prediction on the modified image at point:  14  :  22  is:  8.342585563659668
# STOPS WORKING
# Works!
# Start Point:  150 220
# End Point:  170 240
# END POINT:  168
# Prediction on the modified image at point:  15  :  22  is:  8.349823951721191
# STOPS WORKING
# Works!
# Start Point:  160 220
# End Point:  180 240
# END POINT:  168
# Prediction on the modified image at point:  16  :  22  is:  8.335251808166504
# STOPS WORKING
# Works!
# <PIL.Image.Image image mode=RGBA size=448x336>
